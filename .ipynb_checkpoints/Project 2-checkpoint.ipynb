# %% [markdown]
# # Project 2
# Vasanth Rajasekaran and Sam Childs
#
# ## Collaboration Plan
# To facilitate collaboration, Sam and I have set up a private Github repository to share workbooks and data. We will ensure that each commit to the Git repo will include thorough comments documenting the changes. We also have frequent calls to check in on our progress and help eachother out if there are any areas where one is stuck.

# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
from scipy import stats
import numpy as np

sqlite_file = 'lahman2014.sqlite'
conn = sqlite3.connect(sqlite_file)

# %% [markdown]
# # Part 1 - Wrangling
# ## Problem 1

# %%
q = 'SELECT Teams.teamID, Teams.yearID, Teams.franchID, Teams.W, Teams.G, ((CAST(Teams.W as REAL)/Teams.G) * 100) as winning_percentage, sum(Salaries.salary) as total_payroll FROM Teams, Salaries WHERE Teams.teamID == Salaries.teamID AND Teams.yearID == Salaries.yearID GROUP BY Teams.yearID, Teams.teamID'
t = pd.read_sql(q, conn)
t
# Out:
#     teamID  yearID franchID   W    G  winning_percentage  total_payroll
# 0      ATL    1985      ATL  66  162           40.740741     14807000.0
# 1      BAL    1985      BAL  83  161           51.552795     11560712.0
# 2      BOS    1985      BOS  81  163           49.693252     10897560.0
# 3      CAL    1985      ANA  90  162           55.555556     14427894.0
# 4      CHA    1985      CHW  85  163           52.147239      9846178.0
# ..     ...     ...      ...  ..  ...                 ...            ...
# 853    SLN    2014      STL  90  162           55.555556    120693000.0
# 854    TBA    2014      TBD  77  162           47.530864     72689100.0
# 855    TEX    2014      TEX  67  162           41.358025    112255059.0
# 856    TOR    2014      TOR  83  162           51.234568    109920100.0
# 857    WAS    2014      WSN  96  162           59.259259    131983680.0
#
# [858 rows x 7 columns]

# %%
a = t[t.teamID == 'BOS']
a.winning_percentage.plot.line(x='yearID') # Is this plot meant to answer Part 2 Problem 2? it doesn't feel right
a
# Out:
#     teamID  yearID franchID   W    G  winning_percentage  total_payroll
# 2      BOS    1985      BOS  81  163           49.693252     10897560.0
# 28     BOS    1986      BOS  95  161           59.006211     14402239.0
# 54     BOS    1987      BOS  78  162           48.148148     10144167.0
# 80     BOS    1988      BOS  89  162           54.938272     13896092.0
# 106    BOS    1989      BOS  83  162           51.234568     17481748.0
# 132    BOS    1990      BOS  88  162           54.320988     20558333.0
# 158    BOS    1991      BOS  84  162           51.851852     35167500.0
# 184    BOS    1992      BOS  73  162           45.061728     43610584.0
# 210    BOS    1993      BOS  80  162           49.382716     37120583.0
# 238    BOS    1994      BOS  54  115           46.956522     37859084.0
# 266    BOS    1995      BOS  86  144           59.722222     32455518.0
# 294    BOS    1996      BOS  85  162           52.469136     42393500.0
# 323    BOS    1997      BOS  78  162           48.148148     43558750.0
# 352    BOS    1998      BOS  92  162           56.790123     56757000.0
# 382    BOS    1999      BOS  94  162           58.024691     63497500.0
# 412    BOS    2000      BOS  85  162           52.469136     77940333.0
# 442    BOS    2001      BOS  82  161           50.931677    110035833.0
# 472    BOS    2002      BOS  93  162           57.407407    108366060.0
# 502    BOS    2003      BOS  95  162           58.641975     99946500.0
# 532    BOS    2004      BOS  98  162           60.493827    127298500.0
# 561    BOS    2005      BOS  95  162           58.641975    123505125.0
# 591    BOS    2006      BOS  86  162           53.086420    120099824.0
# 621    BOS    2007      BOS  96  162           59.259259    143026214.0
# 651    BOS    2008      BOS  95  162           58.641975    133390035.0
# 681    BOS    2009      BOS  95  162           58.641975    121345999.0
# 711    BOS    2010      BOS  89  162           54.938272    162447333.0
# 741    BOS    2011      BOS  90  162           55.555556    161762475.0
# 771    BOS    2012      BOS  69  162           42.592593    173186617.0
# 801    BOS    2013      BOS  97  162           59.876543    151530000.0
# 831    BOS    2014      BOS  71  162           43.827160    139019929.0

# %% [markdown]
# In this query we are getting six pieces of data from the db: Teams.teamID, Teams.yearID, Teams.franchID, Teams.W, Teams.G, and Salaries.salary from the Teams and Salaries tables. We then make sure we are calculating the correct payroll by matching the teamID and yearID between both tables. By matching, we are ensured we only populate the new table with teams that have salary data, which are teams after 1985. Thus no teams with missing salary or other data are included in our new table.

# %% [markdown]
# # Part 2: Exploratory Data Analysis
# ## Problem 2

# %%
# Single plot of distributions:
# Maybe a heatmap would be good here...
bins = [0,10000000,20000000,30000000,40000000,50000000,60000000, 70000000, 80000000, 90000000, 100000000,110000000, 120000000, 130000000, 140000000, 150000000]
binRoll = pd.cut(t['total_payroll'], bins=bins )
data = pd.crosstab(binRoll,t.yearID, normalize = True)
heat = sb.heatmap(data) #If I can figure out how to make the crosstab use buckets, vmin\|/
heat.invert_yaxis()

# %%
# Scatter Plot for Win percentage as a function of total payroll
x = t.total_payroll / 1000
y = t.winning_percentage

fig = plt.figure()
payWin = fig.add_axes([0,0,1,1])
payWin.scatter(x,y, color = "#756bb1")
payWin.set_xlabel('Total Payroll (in $1000\'s)')
payWin.set_ylabel('Win Rate')
payWin.set_title('Season Win Rate vs. Team Payroll')
plt.show()

# %% [markdown]
# ## Question 1
# From our heat map we can clearly see there is an increase in the mean of payrolls as time passes. Inititally most teams were under 10 million in terms of payroll in the 80s but now most teams are over 70 million.
#
# From the scatter plot we can see that payroll does increase the average win rate but a little, however, the spread is not linear.

# %% [markdown]
# ## Problem 3

# %%
t.groupby(['yearID']).total_payroll.mean().plot(logy=True)

# %% [markdown]
# The above plot shows the average payroll by year and is scaled logrithmically. We can clearly see a increase over time in the size of payrolls

# %% [markdown]
# ## Problem 4

# %%
# bins = pd.IntervalIndex.from_tuples([(1990, 1995),(1995,2000),(2000,2005),(2005,2010),(2010, 2014)])
bins = [1990,1995,2000,2005,2010,2015]
era = pd.cut(t.yearID,bins).dropna()
era 
# we take averages of teams within the 5 year intervals and plot
# Out:
# 156    (1990, 1995]
# 157    (1990, 1995]
# 158    (1990, 1995]
# 159    (1990, 1995]
# 160    (1990, 1995]
#            ...
# 853    (2010, 2015]
# 854    (2010, 2015]
# 855    (2010, 2015]
# 856    (2010, 2015]
# 857    (2010, 2015]
# Name: yearID, Length: 702, dtype: category
# Categories (5, interval[int64]): [(1990, 1995] < (1995, 2000] < (2000, 2005] < (2005, 2010] < (2010, 2015]]

# %%
# bins is an iterable for the intervals we want
colors = ['#fed976','#feb24c','#fd8d3c','#f03b20','#bd0026']
for per in range(5): #Loop for producing 5 charts
    x = t.total_payroll / 1000
    y = t.winning_percentage

    fig = plt.figure()
    payWin = fig.add_axes([0,0,1,1])
    payWin.scatter(x,y, color = colors[per])
    payWin.set_xlabel('Total Payroll (in $1000\'s)')
    payWin.set_ylabel('Win Rate')
    payWin.set_title('Season Win Rate vs. Team Payroll ' + str(bins[per])[:-1] + ")")
    
    print(x.to_numpy())
    slope, intercept, = stats.linregress(x.to_numpy(),y.to_numpy())
    
    plt.show()
# Out:
# [ 14807.     11560.712  10897.56   14427.894   9846.178  12702.917
#    8359.917   6551.666  10348.143   9993.051   9321.179  10967.917
#    5764.821  11284.107   9470.166  14238.204  10834.762   9058.606
#   10124.966   9227.5    11036.583   4613.      8221.714  11817.083
#    7676.5     8812.55   17102.786  13001.258  14402.239  14427.258
#   10418.819  17208.165  11906.388   7809.5    12335.714   9873.276
#   13043.698  14913.776   8748.167   9943.642  11103.6    18494.253
#   15393.714   9779.421  11590.166  10843.5    11380.693   5958.309
#    8947.      9875.01    6743.119  12611.047  16544.56   13900.273
#   10144.167  12843.499  10641.843  14307.999   9281.5     8513.75
#   12122.881  12608.371  11828.056  13675.403   6397.5     7293.224
#    6942.052  17099.714  13846.714  11680.839  11514.233   7652.
#   11065.796   2263.5     7290.     11758.       880.     10479.501
#   12728.174  13532.075  13896.092  11947.388   6390.     13119.198
#    8888.409   8936.5    12869.571  12286.167  14556.562  16850.515
#   12462.666   8402.      9603.333  19441.152  15269.314   9690.
#   13838.      5998.5     9561.002   7342.45   12380.     12880.
#    5342.131  12241.225  11112.334   8275.167  17481.748  15097.833
#    7265.41   10668.     11072.      9094.5    15146.404  15029.5
#   18683.568  21071.562  15531.666  11533.     13807.389  17114.375
#   19885.071  15613.07   10604.     12737.5    14195.      9779.5
#   14962.834  16078.833  11893.781  16261.666  14555.501   9680.084
#   20558.333  21720.      9491.5    13624.     14370.     14487.
#   17593.238  18330.     23361.084  21318.704  14602.     19719.167
#   16586.388  20912.318  21722.834  19887.501  13173.667  15556.
#   17588.334  12553.667  19335.333  20523.334  14874.372  17756.834
#   18403.5    17519.     35167.5    33060.001  16919.667  23175.667
#   26305.333  17635.     23838.333  12852.5    26319.834  32790.664
#   23361.833  23115.5    10732.333  27344.168  32590.001  36999.167
#   22487.332  23634.667  22150.001  15691.833  30967.666  21860.001
#   18224.5    19902.417  34625.333  23780.667  43610.584  34749.334
#   30160.833  29829.686  35931.499   9373.044  27322.834  15407.5
#   33893.834  44788.166  28027.834  31013.667  15822.334  37543.334
#   44602.002  41035.     24383.834  33944.167  26854.167  23179.833
#   33163.168  27583.836  30128.167  44788.666  41641.417  29096.5
#   37120.583  28588.334  39696.166  39386.666  44879.666  18561.
#   10353.5    38150.165  19330.545  30210.5    41346.167  39331.999
#   28217.933  23806.834  18899.333  42624.9    39043.667  37812.333
#   28538.334  24822.467  25511.333  32696.333  35050.     23367.334
#   36376.959  47279.166  49383.513  38849.769  37859.084  25156.218
#   39183.836  36287.333  40961.833  30490.5    23887.333  41446.501
#   21633.     33126.     40541.334  38000.001  28438.5    24350.5
#   19098.     45731.334  30956.583  34172.5    31599.     24217.25
#   14916.333  29228.5    42638.666  29275.601  32973.597  43433.668
#   47235.445  43942.521  32455.518  31223.171  46961.282  29505.834
#   43144.67   37937.835  34154.717  37044.168  24515.781  34169.834
#   29532.834  39273.201  25410.5    17798.825  12364.     48874.851
#   27674.992  37739.225  30555.945  18355.345  26382.334  36481.311
#   36462.777  37101.     34581.451  50590.     49698.5    54490.315
#   42393.5    28738.     45139.5    33081.     42526.334  48107.36
#   40179.823  23438.     31022.5    28487.     20281.25   35355.
#   23117.     21730.     16264.5    54191.792  24479.5    21243.
#   34314.5    23017.5    28348.172  41328.501  37144.725  40269.667
#   39041.528  29555.083  31135.472  52278.5    58516.4    43558.75
#   57740.     42155.333  49768.     56802.46   43559.667  17272.
#   48692.5    34777.5    34655.     45380.304  34072.5    23655.338
#   19295.5    62241.545  39800.4    24018.5    36656.5    10771.667
#   37363.672  41540.661  35592.378  45456.667  53448.838  47079.833
#   41281.     32347.     61186.     72355.634  56757.     38335.
#   50838.     23005.     60800.166  50484.648  24065.     41322.667
#   42374.     36862.5    48820.     33914.904  27927.5    10641.5
#   66806.867  52077.999  21303.     36297.5    15065.     46861.5
#   54087.036  42565.834  54672.521  27280.     56572.095  51376.
#   55388.166  68703.999  73140.     80605.863  63497.5    25620.
#   62343.     33962.761  72978.462  61935.837  36489.666  21085.
#   54914.     26225.     80862.453  43377.395  21257.5    17903.
#   86734.359  65092.092  24431.833  31692.5    24697.666  49768.179
#   54125.003  46595.057  49778.195  38870.     76709.931  45444.333
#   51464.167  81027.833  84537.836  81447.435  77940.333  31133.5
#   60539.333  46867.2    75880.771  61111.19   58265.167  19872.
#   51289.111  23433.     87924.286  36505.333  16519.5    32994.333
#   92338.26   79509.776  31971.333  47308.     28928.334  54821.
#   58915.     53737.826  61453.863  62765.129  70795.921  44838.332
#   47535.167  85082.999  91936.166  67599.54  110035.833  65653.667
#   64715.833  48986.     93152.001  71541.334  53416.167  35762.5
#   60612.667  35422.5   109105.953  43886.833  24130.     35159.5
#  112287.143  93174.428  33810.75   41663.833  57760.833  39182.833
#   74720.834  63280.167  78538.333  56980.     88633.5    76895.999
#   61721.667 102819.999  92870.367  60493.487 108366.06   57052.833
#   75690.833  45050.39   78909.449  56851.043  55048.     41979.917
#   63448.417  47257.     94850.953  50287.833  40425.     38670.5
#  125928.583  94633.593  40004.167  57954.999  42323.599  41425.
#   80282.668  78299.835  74660.875  34380.    105526.122  76864.333
#   79031.667  80657.    106243.667  73877.5    99946.5    51010.
#   79868.333  59355.667  48584.834  67179.667  49168.     49450.
#   71040.     40518.    105572.62   40627.     55505.     51948.5
#  152749.814 116876.429  50260.834  70780.     54812.429  45210.
#   86959.167  82852.167  83786.666  19630.    103491.667  51269.
#  100534.667  69780.75   90182.5    51623.333 127298.5    65212.5
#   90560.     46615.25   34319.3    65445.167  46832.     42143.042
#   75397.     47609.     92902.001  27528.5    53585.     40897.5
#  184193.95   96660.97   59425.667  92919.167  32227.929  55384.833
#   81515.834  82019.166  83228.333  29556.667  55050.417  50017.
#   62329.166  86457.302  73914.333 123505.125  75178.     87032.933
#   61892.583  41502.5    47839.     69092.     60408.834  76779.
#   36881.     94867.822  83039.     39934.833  56186.    208306.817
#  101305.821  55425.762  95522.     38133.     63290.833  87754.334
#   90199.5    92106.833  29679.067  55849.     45719.5    48581.5
#   59684.226  90156.876  72585.582 120099.824 102750.667  94424.499
#   60909.519  56031.5    41233.     82612.866  14671.5    88694.435
#   47294.    103472.     98447.187  57568.333  63396.006 194663.079
#  101084.963  62243.079  88273.333  46717.75   69896.141  87959.833
#   90056.419  88891.371  34917.967  68228.662  71365.     63143.
#   52067.546  87290.833  93174.808 143026.214 108671.833  99670.332
#   68524.98   61673.267  54041.     94800.369  30507.     87759.
#   67116.5   109251.333 108454.524  70986.5    71439.5   189259.045
#  115231.663  79366.94   89428.213  38537.833  58110.567 106460.833
#   90219.056  90286.823  24123.5    68318.675  81942.8    36947.5
#   66202.712 102365.683  67196.246 133390.035 121189.332 118345.833
#   74117.695  78970.066  68655.5   137685.196  21811.5    88930.414
#   58245.5   119216.333 118588.536  80937.499  56932.766 207896.789
#  137793.376  47967.126  97879.88   48689.783  73677.616 117666.482
#   76594.5    99624.449  43820.597  67712.326  97793.9    54961.
#   73115.666  96726.166  67101.666 121345.999  96068.5   134809.
#   73558.5    81579.166  75201.    115085.145  36834.    102996.414
#   70519.333 113709.    100414.592  80182.502  65299.266 201449.189
#  149373.987  61910.    113004.046  48693.     43333.7    98904.166
#   83026.45   88528.409  63313.034  68178.798  80538.3    59928.
#   60718.166  84423.666  81612.5   162447.333 105530.    146609.
#   71761.542  61203.966  84227.    122864.928  57029.719  92355.5
#   71405.21  104963.866  95358.016  81108.278  97559.166 206333.389
#  134422.942  55254.9   141928.379  34943.     37799.3    86510.
#   98641.333  93540.751  71923.471  55250.544  62234.     61400.
#   53639.833  87002.692  85304.038 161762.475 127789.    125047.329
#   75947.134  48776.566  88148.071 105700.231  56944.     70694.
#   35712.    138543.166 104188.999  85497.333 112737.    202275.028
#  118847.309  66536.5   172976.379  45047.     45869.14   86110.6
#  118198.333 105433.572  41053.571  92299.264  62567.8    63856.928
#   73804.833  82829.942  77353.999 173186.617  96919.5    88197.033
#   82203.616  78430.3    78069.571 132300.     60651.     60916.225
#  154485.166  95143.575 118078.     97653.944  94085.    196522.289
#   93353.983  55372.5   174538.938  62951.999  55244.7    81978.1
#  117620.683 110300.862  64173.5   120510.974  75009.2    80855.143
#   90132.     87871.525  84393.333 151530.    120065.277 100567.726
#  106404.462  75771.8    74409.071 145989.5    17890.7    80091.725
#  124174.75  223362.196  33601.9    76947.033  75337.5   231978.886
#   49448.346  60132.5   169863.189  77062.     65585.5    74005.043
#  140180.334  92260.11   52955.272 112522.6   126288.1   113703.27
#   97861.5    97609.    103416.    139019.929  81830.5    65522.5
#  108217.5    82151.899  95403.5   152855.5    35116.3    74594.075
#  121988.25  217014.6    41836.9   101217.     83762.5   197543.907
#   30750.     72408.4   180944.967  77178.     75685.7    92531.1
#   20000.    120693.     72689.1   112255.059 109920.1   131983.68 ]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-1cb9fc192438> in <module>
#      13
#      14     print(x.to_numpy())
# ---> 15     slope, intercept, = stats.linregress(x.to_numpy(),y.to_numpy())
#      16
#      17     plt.show()
#
# ValueError: too many values to unpack (expected 2)
