# %% [markdown]
# # Project 2
# Vasanth Rajasekaran and Sam Childs
#
# ## Collaboration Plan
# To facilitate collaboration, Sam and I have set up a private Github repository to share workbooks and data. We will ensure that each commit to the Git repo will include thorough comments documenting the changes. We also have frequent calls to check in on our progress and help eachother out if there are any areas where one is stuck.

# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
from scipy import stats
import numpy as np

sqlite_file = 'lahman2014.sqlite'
conn = sqlite3.connect(sqlite_file)

# %% [markdown]
# # Part 1 - Wrangling
# ## Problem 1

# %%
q = 'SELECT Teams.teamID, Teams.yearID, Teams.franchID, Teams.W, Teams.G, ((CAST(Teams.W as REAL)/Teams.G) * 100) as winning_percentage, sum(Salaries.salary) as total_payroll FROM Teams, Salaries WHERE Teams.teamID == Salaries.teamID AND Teams.yearID == Salaries.yearID GROUP BY Teams.yearID, Teams.teamID'
t = pd.read_sql(q, conn)
t
# Out:
#     teamID  yearID franchID   W    G  winning_percentage  total_payroll
# 0      ATL    1985      ATL  66  162           40.740741     14807000.0
# 1      BAL    1985      BAL  83  161           51.552795     11560712.0
# 2      BOS    1985      BOS  81  163           49.693252     10897560.0
# 3      CAL    1985      ANA  90  162           55.555556     14427894.0
# 4      CHA    1985      CHW  85  163           52.147239      9846178.0
# ..     ...     ...      ...  ..  ...                 ...            ...
# 853    SLN    2014      STL  90  162           55.555556    120693000.0
# 854    TBA    2014      TBD  77  162           47.530864     72689100.0
# 855    TEX    2014      TEX  67  162           41.358025    112255059.0
# 856    TOR    2014      TOR  83  162           51.234568    109920100.0
# 857    WAS    2014      WSN  96  162           59.259259    131983680.0
#
# [858 rows x 7 columns]

# %%
a = t[t.teamID == 'BOS']
a.winning_percentage.plot.line(x='yearID')
a
# Out:
#     teamID  yearID franchID   W    G  winning_percentage  total_payroll
# 2      BOS    1985      BOS  81  163           49.693252     10897560.0
# 28     BOS    1986      BOS  95  161           59.006211     14402239.0
# 54     BOS    1987      BOS  78  162           48.148148     10144167.0
# 80     BOS    1988      BOS  89  162           54.938272     13896092.0
# 106    BOS    1989      BOS  83  162           51.234568     17481748.0
# 132    BOS    1990      BOS  88  162           54.320988     20558333.0
# 158    BOS    1991      BOS  84  162           51.851852     35167500.0
# 184    BOS    1992      BOS  73  162           45.061728     43610584.0
# 210    BOS    1993      BOS  80  162           49.382716     37120583.0
# 238    BOS    1994      BOS  54  115           46.956522     37859084.0
# 266    BOS    1995      BOS  86  144           59.722222     32455518.0
# 294    BOS    1996      BOS  85  162           52.469136     42393500.0
# ...

# %% [markdown]
# In this query we are getting six pieces of data from the db: Teams.teamID, Teams.yearID, Teams.franchID, Teams.W, Teams.G, and Salaries.salary from the Teams and Salaries tables. We then make sure we are calculating the correct payroll by matching the teamID and yearID between both tables. By matching, we are ensured we only populate the new table with teams that have salary data, which are teams after 1985. Thus no teams with missing salary or other data are included in our new table.
#
# Boston is graphed over time in the graph above (since the df is sorted by time), and we see a clear chance in winning percent over time.

# %% [markdown]
# # Part 2: Exploratory Data Analysis
# ## Problem 2

# %%
# create bin in intervals of 10,000,000
bins = [0,10000000,20000000,30000000,40000000,50000000,60000000, 70000000, 80000000, 90000000, 100000000,110000000, 120000000, 130000000, 140000000, 150000000]
binRoll = pd.cut(t['total_payroll'], bins=bins ) # use cut to create buckets 
data = pd.crosstab(binRoll,t.yearID, normalize = True)
heat = sb.heatmap(data) # create heatmap 
heat.invert_yaxis()

# %%
# Scatter Plot for Win percentage as a function of total payroll
x = t.total_payroll / 1000
y = t.winning_percentage

fig = plt.figure()
payWin = fig.add_axes([0,0,1,1])
payWin.scatter(x,y, color = "#756bb1")
payWin.set_xlabel('Total Payroll (in $1000\'s)') # sets x and y axis labels
payWin.set_ylabel('Win Rate')
payWin.set_title('Season Win Rate vs. Team Payroll')
plt.show()

# %% [markdown]
# ## Question 1
# From our heat map we can clearly see there is an increase in the mean of payrolls as time passes. Inititally most teams were under 10 million in terms of payroll in the 80s but now most teams are over 70 million.
#
# From the scatter plot we can see that payroll does increase the average win rate but a little, however, the spread is not linear.

# %% [markdown]
# ## Problem 3

# %%
t.groupby(['yearID']).total_payroll.mean().plot(logy=True) # plot using groupby

# %% [markdown]
# The above plot shows the average payroll by year and is scaled logrithmically. We can clearly see a increase over time in the size of payrolls

# %% [markdown]
# ## Problem 4

# %%
def generate_labels(x,y,labels, ax): # function used to generate team labels in later graphs 
    a = pd.concat({'x': x, 'y': y, 'labels': labels}, axis = 1)
    for idk, point in a.iterrows():
        ax.text(point['x'], point['y'], str(point['labels']))
        
        
v = t.copy()
bins = [1990,1995,2000,2005,2010,2015] # set bins and labels
labels = ['90-94','95-99', '00-04','05-09','10-14']
v['interval'] = pd.cut(t.yearID,bins, labels=labels).dropna() # create a new df with intervals marked per row

# %%
colors = ['#fed976','#feb24c','#fd8d3c','#f03b20','#bd0026']
for per in range(5): #Loop for producing 5 charts for each interval
    temp = v[v.interval == labels[per]] # gets current interval
    x = temp.total_payroll / 1000 
    y = temp.winning_percentage

    fig = plt.figure()
    payWin = fig.add_axes([0,0,1,1])
    payWin.scatter(x,y, color = colors[per])
    payWin.set_xlabel('Total Payroll (in $1000\'s)') # label axis and title
    payWin.set_ylabel('Win Rate')
    payWin.set_title('Season Win Rate vs. Team Payroll ' + str(labels[per]))

    # Label Points
    generate_labels(x, y, temp['teamID'], payWin) # create team labels
    
    # Run regression and plot line
    x = np.asarray(x) # turn x y intern np arrays 
    y = np.asarray(y)
    slope, intercept, r_value, p_value, std_err = stats.linregress(x,y) # create liner regression 
    plt.plot(x, intercept + slope*x, 'r', label='fitted line', color = "#756bb1") # plot regression
    
    plt.show()

# %% [markdown]
# ## Question 2:
# Overall team payrolls have expanded, but part of this is explained by the Yankees being capped by the competitive balance tax and everyone else catching up. Part of this growth may be explained by overall inflation as well.
#
# Oakland had a significantly larger winrate for its total payroll, especially in 2000-2005. The reason their efficiency declined from 2005 on was because total payroll increased without a corresponding increase in winrate.
#
# Other teams that stand out for efficiency are Montreal in the 1990-1994 range, but their winrate declined in the back half of the 90's and ultimately they relocated to DC and rebranded as the Nationals in 2004.

# %% [markdown]
# # Part 3: Data Transformations
# ## Problem 5

# %%
standard = t.groupby(['yearID']).total_payroll.transform('std') # get std by year 
average = t.groupby(['yearID']).total_payroll.transform('mean') # calc mean by year 
t['z-score'] = (t.total_payroll - average)/standard # standardization function
t.head()
# Out:
#   teamID  yearID franchID   W    G  winning_percentage  total_payroll  \
# 0    ATL    1985      ATL  66  162           40.740741     14807000.0
# 1    BAL    1985      BAL  83  161           51.552795     11560712.0
# 2    BOS    1985      BOS  81  163           49.693252     10897560.0
# 3    CAL    1985      ANA  90  162           55.555556     14427894.0
# 4    CHA    1985      CHW  85  163           52.147239      9846178.0
#
#     z-score
# 0  1.914905
# 1  0.601068
# 2  0.332678
# 3  1.761474
# 4 -0.092838

# %% [markdown]
# ## Problem 6

# %%
v2 = t.copy()
bins = [1990,1995,2000,2005,2010,2015]
labels = ['90-94','95-99', '00-04','05-09','10-14']
v2['interval'] = pd.cut(v2.yearID,bins, labels=labels).dropna()
for per in range(5): #Loop for producing 5 charts
    temp = v2[v2.interval == labels[per]]
    x = temp['z-score']
    y = temp.winning_percentage

    fig = plt.figure()
    payWin = fig.add_axes([0,0,1,1])
    payWin.scatter(x,y, color = colors[per])
    payWin.set_xlabel('Z-Score of Payroll')
    payWin.set_ylabel('Win Rate')
    payWin.set_title('Season Win Rate vs. Team Standardized Payroll ' + str(labels[per]))

    # Label Points
    generate_labels(x, y, temp['teamID'], payWin)
    
    # Run regression and plot line
    x = np.asarray(x)
    y = np.asarray(y)
    slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
    plt.plot(x, intercept + slope*x, 'r', label='fitted line', color = "#756bb1")
    plt.show()

# %% [markdown]
# ## Question 3
# The plots change in subtle ways as each point now has a Z-score for payroll as opposed to the nominal amount in dollars. Essentially we are compressing our axis for payroll to normalize outliers. When we view the graphs' leftward skews in nominal terms, a lot of the teams are compressed, and only the labels for the outliers are visible. By using a Z-Score for our payroll axis, the distribution's skew is harder to see, but at the same time, the values in the cluster are more visible.
#
# As for whether using a Z-score gives us a better understanding of the relationship between Payroll and Win rate, I think either way, we only see a light correlation between payroll and winrate. This supports the underlying philosophy of Moneyball, that money isn't everything, efficiency is king.

# %% [markdown]
# ## Problem 7

# %%
# scatter of all payrolls standardized 
x = t['z-score']
y = t.winning_percentage
fig = plt.figure()
payWin = fig.add_axes([0,0,1,1])
payWin.scatter(x,y, color = colors[per])
payWin.set_xlabel('Z-Score of Payroll')
payWin.set_ylabel('Win Rate')
#generate_labels(x, y, t['teamID'], payWin)
x = np.asarray(x)
y = np.asarray(y)
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y) # calc liner regression 
plt.plot(x, intercept + slope*x, 'r', label='fitted line', color = "#756bb1")

plt.show()

# %% [markdown]
# ## Problem 8

# %%
t['efficiency'] = t.winning_percentage - (50+2.5*t['z-score']) # calc efficiency using equation
t.head()
# Out:
#   teamID  yearID franchID   W    G  winning_percentage  total_payroll  \
# 0    ATL    1985      ATL  66  162           40.740741     14807000.0
# 1    BAL    1985      BAL  83  161           51.552795     11560712.0
# 2    BOS    1985      BOS  81  163           49.693252     10897560.0
# 3    CAL    1985      ANA  90  162           55.555556     14427894.0
# 4    CHA    1985      CHW  85  163           52.147239      9846178.0
#
#     z-score  efficiency
# 0  1.914905  -14.046522
# 1  0.601068    0.050124
# 2  0.332678   -1.138442
# 3  1.761474    1.151872
# 4 -0.092838    2.379333

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
for team in ['OAK', 'BOS', 'NYA', 'ATL', 'TBA']: # plot the listed teams and their efficiency over time 
    ax.plot(t[(t.teamID == team)].yearID,t[(t.teamID == team)].efficiency, label = team)
ax.legend(loc=1)
plt.show()

# %% [markdown]
# ## Question 4:
# This plot allows us to contextualize the data we analyzed in questions 2 and 3 through the lens of efficiency. While all of the information regarding efficiency is encoded into the graphs in section 2 and 3, it is hard to understand while spread along 2 axes (winrate and payroll). By giving efficiency its own graph, we can see that Oakland was highly efficient in the Moneyball period, followed by a decline leading into the great recession, and a return to form throughout Obama's second term.
