# %% [markdown]
# # Data Science Project 1
# Vasanth Rajasekaran and Sam Childs

# %% [markdown]
# ## Collaboration Plan

# %% [markdown]
# ### Step One

# %%
# !pip install lxml
# Out:
# ...
#      |████████████████████████████████| 5.4 MB 3.6 MB/s eta 0:00:01     |█                               | 174 kB 1.4 MB/s eta 0:00:04     |██                              | 348 kB 1.4 MB/s eta 0:00:04     |██████████                      | 1.7 MB 1.4 MB/s eta 0:00:03     |███████████▉                    | 2.0 MB 1.4 MB/s eta 0:00:03     |█████████████████████▊          | 3.7 MB 3.6 MB/s eta 0:00:01     |███████████████████████████▉    | 4.7 MB 3.6 MB/s eta 0:00:01
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json 
import lxml
import re
url = 'https://www.spaceweatherlive.com/en/solar-activity/top-50-solar-flares'
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
response = requests.get(url, headers=headers)
content = response.content

# %%
a = BeautifulSoup(content)
a.prettify()
solarTable = a.find('table')
table = pd.read_html(solarTable.prettify())
table=table[0]
table.columns = ['rank','x_class', 'date', 'region' ,'start_time', 'max_time', 'end_time', 'movie']
table
# Out:
#     rank x_class        date  region start_time max_time end_time  \
# 0      1    X28+  2003/11/04     486      19:29    19:53    20:06
# 1      2    X20+  2001/04/02    9393      21:32    21:51    22:03
# 2      3  X17.2+  2003/10/28     486      09:51    11:10    11:24
# 3      4    X17+  2005/09/07     808      17:17    17:40    18:03
# 4      5   X14.4  2001/04/15    9415      13:19    13:50    13:55
# 5      6     X10  2003/10/29     486      20:37    20:49    21:01
# 6      7    X9.4  1997/11/06    8100      11:49    11:55    12:01
# 7      8    X9.3  2017/09/06    2673      11:53    12:02    12:10
# 8      9      X9  2006/12/05     930      10:18    10:35    10:45
# 9     10    X8.3  2003/11/02     486      17:03    17:25    17:39
# 10    11    X8.2  2017/09/10    2673      15:35    16:06    16:31
# 11    12    X7.1  2005/01/20     720      06:36    07:01    07:26
# 12    13    X6.9  2011/08/09    1263      07:48    08:05    08:08
# ...

# %%
import datetime
del table['movie']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/conda/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2888             try:
# -> 2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'movie'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-ca2c5f5e619a> in <module>
#       1 import datetime
# ...

# %%
import re
url2 = 'https://cdaw.gsfc.nasa.gov/CME_list/radio/waves_type2.html'
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
response2 = requests.get(url2, headers=headers)
content2 = response2.content

# %%
b = BeautifulSoup(content2, "html.parser")

#print(b)
bString = str(b)
cutB = bString.split("\n")
dataLines = cutB[15:-3]
#"""

data = {"Start Date": [],
        "Start Time": [],
        "End Date": [],
        "End Time": [],
        "Max Frequency": [],
        "Min Frequency": [],
        "Location": [],
        "NOAA": [],
        "Imp": [],
        "CME Date": [],
        "CME Time": [],
        "CPA": [],
        "Width": [],
        "Speed": [],
                          }
        
    
dfNasa = pd.DataFrame(data)

for row in range(len(dataLines)):
    dLCuts = dataLines[row].split(" ")
    print(dLCuts)
    insertRow = pd.Series({"Start Date": dLCuts[0],
                           "Start Time": dLCuts[1],
                           "End Date": dLCuts[2],
                           "End Time": dLCuts[3],
                           "Max Frequency": dLCuts[5],
                           "Min Frequency": dLCuts[7],
                           "Flare Location": dLCuts[10],
                           "NOAA": dLCuts[12],
                           "Imp": dLCuts[13],
                           "CME Date": dLCuts[17],
                           "CME Time": dLCuts[18],
                           "CPA": dLCuts[19],
                           "Width": dLCuts[26],
                           "Speed": dLCuts[29],
                        
                          })
    dfNasa = dfNasa.append(insertRow, ignore_index = True)
dfNasa.head()
# Out:
# ['1997/04/01', '14:00', '04/01', '14:15', '', '<a', 'href="https://cdaw.gsfc.nasa.gov/CME_list/daily_movies/1997/04/01/c2rdif_waves.html">8000</a>', '', '<a', 'href="https://cdaw.gsfc.nasa.gov/CME_list/daily_movies/1997/04/01/c3rdif_waves.html">4000</a>', '', '', 'S25E16', '', '8026', 'M1.3', '', '', '<a', 'href="https://cdaw.gsfc.nasa.gov/CME_list/UNIVERSAL/1997_04/jsmovies/1997_04/19970401.151838.p073g/c2_rdif.html">04/01</a>', '15:18', '', '', '74', '', '', '79', '', '<a', 'href="https://cdaw.gsfc.nasa.gov/CME_list/UNIVERSAL/1997_04/htpng/19970401.151838.p073g.htp.html">312</a>', '', '', '<a', 'href="https://cdaw.gsfc.nasa.gov/CME_list/daily_plots/sephtx/1997_04/sephtx_19970401.png">PHTX</a>']
# ...

# %%
rowList = []
for row in range(0,len(dataLines)):
    #dLCuts = dataLines[row].split(" ")
    # Regex + Int(): 6, 9, 29
    # Regex: 19,
    # Int: 
    # N/A + Int(): 14
    insertRow = pd.Series({"Start Date": dLCuts[0],
                          "Start Time": dLCuts[1],
                           "End Date": dLCuts[2],
                           "End Time": dLCuts[3],
                           "Max Frequency": dLCuts[6],
                           "Min Frequency": dLCuts[9],
                           "Location": dLCuts[12],
                           "NOAA": dLCuts[14],
                           "Imp": dLCuts[15],
                           "CME Date": dLCuts[19],
                           "CME Time": dLCuts[20],
                           "CPA": dLCuts[23],
                           "Width": dLCuts[26],
                           "Speed": dLCuts[29]
                          })
    rowList.append(insertRow)
df = pd.DataFrame(rowList)
df.head()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-308a39cd2f77> in <module>
#      19                            "CPA": dLCuts[23],
#      20                            "Width": dLCuts[26],
# ---> 21                            "Speed": dLCuts[29]
#      22                           })
#      23     rowList.append(insertRow)
#
# IndexError: list index out of range
